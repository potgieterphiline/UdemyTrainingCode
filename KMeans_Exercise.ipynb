# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/CIA_Country_Facts.csv')

# %%
df.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 20 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             227 non-null    object
#  1   Region                              227 non-null    object
#  2   Population                          227 non-null    int64
#  3   Area (sq. mi.)                      227 non-null    int64
#  4   Pop. Density (per sq. mi.)          227 non-null    float64
#  5   Coastline (coast/area ratio)        227 non-null    float64
#  6   Net migration                       224 non-null    float64
#  7   Infant mortality (per 1000 births)  224 non-null    float64
#  8   GDP ($ per capita)                  226 non-null    float64
#  9   Literacy (%)                        209 non-null    float64
#  10  Phones (per 1000)                   223 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP ($ per capita)                     1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
sns.histplot(data=df[df['Population']<1.749777e+07],x='Population')
# Out:
# <Axes: xlabel='Population', ylabel='Count'>

# %%
sns.barplot(data=df,x='Region',y='GDP ($ per capita)')
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='GDP ($ per capita)',y='Phones (per 1000)',hue='Region')
plt.legend(bbox_to_anchor=(1.1, 0.5), loc='center left')

# %%
df[df['Phones (per 1000)']>1000]
# Out:
#     Country                               Region  Population  Area (sq. mi.)  \
# 138  Monaco  WESTERN EUROPE                            32543               2
#
#      Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  Net migration  \
# 138                     16271.5                         205.0           7.75
#
#      Infant mortality (per 1000 births)  GDP ($ per capita)  Literacy (%)  \
# 138                                5.43             27000.0          99.0
#
#      Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 138             1035.6         0.0        0.0      100.0      NaN       9.19
#
#      Deathrate  Agriculture  Industry  Service
# 138      12.91         0.17       NaN      NaN

# %%
df[df['GDP ($ per capita)']>50000]
# Out:
#         Country                               Region  Population  \
# 121  Luxembourg  WESTERN EUROPE                           474413
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 121            2586                       183.5                           0.0
#
#      Net migration  Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 121           8.97                                4.81             55100.0
#
#      Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  \
# 121         100.0              515.4       23.28        0.4      76.32
#
#      Climate  Birthrate  Deathrate  Agriculture  Industry  Service
# 121      NaN      11.94       8.41         0.01      0.13     0.86

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(data=df,x='GDP ($ per capita)',y='Literacy (%)',hue='Region')
plt.legend(bbox_to_anchor=(1.1, 0.5), loc='center left')

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.select_dtypes(include=np.number).corr(), annot=True)
plt.title('Correlation Heatmap of Numeric Columns')
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.clustermap(df.select_dtypes(include=np.number).corr())
plt.title('Correlation Heatmap of Numeric Columns')
plt.show()

# %%
df[df['Agriculture'].isnull()]['Country']
# Out:
# 3            American Samoa
# 4                   Andorra
# 78                Gibraltar
# 80                Greenland
# 83                     Guam
# 134                 Mayotte
# 140              Montserrat
# 144                   Nauru
# 153      N. Mariana Islands
# 171            Saint Helena
# 174    St Pierre & Miquelon
# 177              San Marino
# 208       Turks & Caicos Is
# 221       Wallis and Futuna
# 223          Western Sahara
# Name: Country, dtype: object

# %%
df[df['Agriculture'].isnull()] = df[df['Agriculture'].isnull()].fillna(0)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Climate                               18
# Literacy (%)                          13
# Phones (per 1000)                      2
# Deathrate                              2
# Birthrate                              1
# Industry                               1
# Service                                1
# Crops (%)                              1
# Arable (%)                             1
# Other (%)                              1
# Infant mortality (per 1000 births)     1
# Net migration                          1
# Area (sq. mi.)                         0
# Population                             0
# Region                                 0
# Country                                0
# GDP ($ per capita)                     0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Agriculture                            0
# dtype: int64

# %%
df['Climate'] = df['Climate'].fillna(df.groupby('Region')['Climate'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          1
# Infant mortality (per 1000 births)     1
# GDP ($ per capita)                     0
# Literacy (%)                          13
# Phones (per 1000)                      2
# Arable (%)                             1
# Crops (%)                              1
# Other (%)                              1
# Climate                                0
# Birthrate                              1
# Deathrate                              2
# Agriculture                            0
# Industry                               1
# Service                                1
# dtype: int64

# %%
df['Literacy (%)'] = df['Literacy (%)'].fillna(df.groupby('Region')['Literacy (%)'].transform('mean'))

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         1
# Infant mortality (per 1000 births)    1
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     2
# Arable (%)                            1
# Crops (%)                             1
# Other (%)                             1
# Climate                               0
# Birthrate                             1
# Deathrate                             2
# Agriculture                           0
# Industry                              1
# Service                               1
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Country                               0
# Region                                0
# Population                            0
# Area (sq. mi.)                        0
# Pop. Density (per sq. mi.)            0
# Coastline (coast/area ratio)          0
# Net migration                         0
# Infant mortality (per 1000 births)    0
# GDP ($ per capita)                    0
# Literacy (%)                          0
# Phones (per 1000)                     0
# Arable (%)                            0
# Crops (%)                             0
# Other (%)                             0
# Climate                               0
# Birthrate                             0
# Deathrate                             0
# Agriculture                           0
# Industry                              0
# Service                               0
# dtype: int64

# %%
df_t = df.drop(columns=['Country'])

# %%
X = pd.get_dummies(df_t)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
ssd =[]

for k in range(2,30):
  model = KMeans(n_clusters=k)
  model.fit(X_scaled)
  ssd.append(model.inertia_)

# %%
plt.plot(range(2,30),ssd,'o--')

# %%
model = KMeans(n_clusters=6)
model.fit(X_scaled)
# Out:
# KMeans(n_clusters=6)

# %%
model.labels_
# Out:
# array([3, 4, 5, 0, 4, 2, 1, 1, 1, 1, 1, 0, 4, 2, 1, 5, 5, 1, 4, 4, 1, 3,
#        4, 3, 1, 4, 2, 1, 1, 5, 4, 3, 3, 3, 5, 3, 5, 1, 4, 3, 3, 1, 5, 1,
#        3, 3, 2, 1, 3, 4, 1, 4, 4, 2, 1, 1, 1, 5, 1, 2, 2, 4, 3, 4, 0, 4,
#        4, 1, 0, 2, 3, 5, 1, 4, 3, 5, 4, 5, 1, 1, 0, 1, 3, 3, 1, 3, 1, 5,
#        4, 4, 5, 5, 5, 5, 4, 4, 5, 4, 1, 4, 4, 5, 1, 2, 0, 5, 5, 5, 1, 3,
#        4, 5, 2, 3, 5, 4, 4, 4, 5, 4, 3, 3, 5, 5, 3, 4, 0, 1, 3, 4, 3, 1,
#        0, 4, 5, 1, 5, 3, 2, 0, 3, 4, 1, 0, 0, 1, 3, 3, 0, 4, 5, 5, 0, 1,
#        0, 1, 1, 5, 4, 4, 1, 5, 1, 4, 5, 3, 2, 1, 1, 5, 1, 0, 4, 3, 5, 3,
#        1, 3, 5, 4, 4, 0, 3, 2, 4, 5, 3, 1, 2, 4, 4, 5, 5, 2, 3, 5, 3, 0,
#        1, 5, 5, 2, 1, 0, 3, 4, 5, 4, 4, 1, 2, 0, 1, 5, 1, 0, 5, 5, 5, 2,
#        2], dtype=int32)

# %%
X['K=6 Cluster Labels'] = model.labels_

# %%
X.corr()['K=6 Cluster Labels'].sort_values(ascending=False).iloc[1:].plot(kind='bar')
# Out:
# <Axes: >

# %%
# !pip install plotly

# %%
iso_codes = pd.read_csv('/content/sample_data/country_iso_codes.csv')

# %%
iso_codes.head()
# Out:
#                                            Country  \
# 0                                      Afghanistan
# 1  Akrotiri and Dhekelia – See United Kingdom, The
# 2                                    Åland Islands
# 3                                          Albania
# 4                                          Algeria
#
#                                           ISO Code
# 0                                              AFG
# 1  Akrotiri and Dhekelia – See United Kingdom, The
# 2                                              ALA
# 3                                              ALB
# 4                                              DZA

# %%
df['ISO Code'] = df['Country'].map(iso_codes)

# %%
df
# Out:
#                Country                               Region  Population  \
# 0          Afghanistan        ASIA (EX. NEAR EAST)             31056997
# 1              Albania  EASTERN EUROPE                          3581655
# 2              Algeria  NORTHERN AFRICA                        32930091
# 3       American Samoa  OCEANIA                                   57794
# 4              Andorra  WESTERN EUROPE                            71201
# ..                 ...                                  ...         ...
# 180            Vietnam        ASIA (EX. NEAR EAST)             84402966
# 181  Wallis and Futuna  OCEANIA                                   16025
# 182              Yemen  NEAR EAST                              21456188
# 183             Zambia  SUB-SAHARAN AFRICA                     11502010
# 184           Zimbabwe  SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# ...

# %%
cluster_results = pd.DataFrame(model.labels_, index=X.index, columns=['Cluster'])
df = df.merge(cluster_results, left_index=True, right_index=True)

# %%
import plotly.express as px
fig = px.choropleth(df, locations='ISO Code', color='GDP ($ per capita)', hover_name='Country',
                    color_continuous_scale=px.colors.sequential.Plasma)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
