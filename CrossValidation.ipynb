# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/sample_data/Advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha=100)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 7.34177578903413

# %%
model2 = Ridge(alpha=1)

# %%
model2.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_pred2 = model2.predict(X_test)

# %%
mean_squared_error(y_test,y_pred2)
# Out:
# 2.319021579428752

# %% [markdown]
# #split data into 3: Test, Validation, Train

# %%
X_train, X_other, y_train, y_other = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
X_eval, X_test, y_eval, y_test = train_test_split(X_other, y_other, test_size=0.5, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
X_test
# Out:
# array([[-1.81157372, -1.6012956 , -1.48085784],
#        [-1.81575718, -1.50653432, -1.50812956],
#        [-1.79317778, -1.68363672, -1.4745308 ],
#        [-1.7842897 , -1.67949667, -1.47823975],
#        [-1.77996538, -1.56817515, -1.51685651],
#        [-1.81427818, -1.64223616, -1.48063966],
#        [-1.79926281, -1.68363672, -1.50267521],
#        [-1.79719221, -1.5129744 , -1.43853212],
#        [-1.78534613, -1.5718552 , -1.50878408],
#        [-1.81292595, -1.64039614, -1.42675074],
#        [-1.81946172, -1.62245589, -1.41256945],
#        [-1.81967301, -1.52585458, -1.42216909],
#        [-1.7921777 , -1.65695636, -1.46318576],
#        [-1.81160189, -1.6528163 , -1.51882007],
#        [-1.80541827, -1.6155558 , -1.43656856],
#        [-1.79317778, -1.68133669, -1.44529551],
#        [-1.80481258, -1.62797597, -1.50900225],
#        [-1.79403701, -1.53275467, -1.35584427],
#        [-1.78372627, -1.49411415, -1.50987495],
#        [-1.7823177 , -1.47065383, -1.429587  ],
# ...

# %%
X_eval = scaler.transform(X_eval)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model_A = Ridge(alpha=100)

# %%
model_A.fit(X_train,y_train)
# Out:
# Ridge(alpha=100)

# %%
y_eval_pred = model_A.predict(X_eval)

# %%
mean_squared_error(y_eval,y_eval_pred)
# Out:
# 7.320101458823871

# %%
model_B = Ridge(alpha=1)

# %%
model_B.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_eval_pred_B = model_B.predict(X_eval)

# %%
mean_squared_error(y_eval,y_eval_pred_B)
# Out:
# 2.383783075056986

# %%
y_final_pred = model_B.predict(X_test)

# %%
mean_squared_error(y_test,y_final_pred)
# Out:
# 130.05131347685392

# %% [markdown]
# #cross_val_score *function*

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(x_test)

# %%
model = Ridge(alpha=100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
scores
# Out:
# array([ -9.32552967,  -4.9449624 , -11.39665242,  -7.0242106 ,
#         -8.38562723])

# %%
abs(scores.mean())
# Out:
# np.float64(8.215396464543607)

# %%
model = Ridge(alpha=1)

# %%
scores = cross_val_score(model,X_train,y_train,scoring='neg_mean_squared_error',cv=5)

# %%
scores
# Out:
# array([-3.15513238, -1.58086982, -5.40455562, -2.21654481, -4.36709384])

# %%
abs(scores.mean())
# Out:
# np.float64(3.344839296530695)

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_test_pred = model.predict(X_test)

# %%
mean_squared_error(y_test,y_final_test_pred)
# Out:
# 2.319021579428752

# %% [markdown]
# #cross_validate function

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_test = scaler.transform(x_test)

# %%
X_train = scaler.transform(X_train)

# %%
from sklearn.model_selection import cross_validate

# %%
model = Ridge(alpha=1)

# %%
scores = cross_validate(model,X_train,y_train,
                        scoring=['neg_mean_squared_error','neg_mean_absolute_error'],cv=10)

# %%
scores = pd.DataFrame(scores)

# %%
scores
# Out:
#    fit_time  score_time  test_neg_mean_squared_error  \
# 0  0.001792    0.001473                    -2.962508
# 1  0.001302    0.001373                    -3.057378
# 2  0.001235    0.001248                    -2.173740
# 3  0.001236    0.001260                    -0.833034
# 4  0.001186    0.001304                    -3.464018
# 5  0.001210    0.001212                    -8.232647
# 6  0.001196    0.001204                    -1.905864
# 7  0.001144    0.001256                    -2.765048
# 8  0.001148    0.001208                    -4.989505
# 9  0.001206    0.001217                    -2.846438
#
#    test_neg_mean_absolute_error
# 0                     -1.457174
# 1                     -1.555308
# 2                     -1.238770
# 3                     -0.768938
# 4                     -1.434489
# 5                     -1.494316
# 6                     -1.081362
# 7                     -1.250011
# 8                     -1.580971
# 9                     -1.223326

# %%
scores.mean()
# Out:
# fit_time                        0.001265
# score_time                      0.001275
# test_neg_mean_squared_error    -3.323018
# test_neg_mean_absolute_error   -1.308467
# dtype: float64

# %%
model.fit(X_train,y_train)
# Out:
# Ridge(alpha=1)

# %%
y_final_pred = model.predict(X_test)

# %%
mean_squared_error(y_test,y_final_pred)
# Out:
# 2.319021579428752

# %% [markdown]
# #grid search

# %%
X = df.drop('sales', axis=1)
y = df['sales']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
scaler = StandardScaler()
scaler.fit(X_train)

X_test = scaler.transform(X_test)
X_train = scaler.transform(X_train)

# %%
from sklearn.linear_model import ElasticNet

# %%
base_net_model = ElasticNet()

# %%
param_grid = {'alpha':[0.1,1,5,10,50,100],'l1_ratio':[.1,.5,.7,.95,.99,1]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_model = GridSearchCV(estimator=base_net_model,
                          param_grid=param_grid,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=2)

# %%
grid_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.1; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.5; total time=   0.0s
# [CV] END ............................alpha=0.1, l1_ratio=0.7; total time=   0.0s
# ...

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=0.1, l1_ratio=1)

# %%
grid_model.best_params_
# Out:
# {'alpha': 0.1, 'l1_ratio': 1}

# %%
pd.DataFrame(grid_model.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0        0.001627      0.000131         0.000929        0.000018          0.1
# 1        0.001838      0.000344         0.001479        0.001020          0.1
# 2        0.001481      0.000035         0.000907        0.000011          0.1
# 3        0.001535      0.000127         0.000896        0.000012          0.1
# 4        0.001477      0.000020         0.000971        0.000139          0.1
# 5        0.001514      0.000090         0.000904        0.000029          0.1
# 6        0.001466      0.000016         0.000903        0.000019          1.0
# 7        0.001488      0.000014         0.000897        0.000021          1.0
# 8        0.001473      0.000028         0.000887        0.000032          1.0
# 9        0.001485      0.000020         0.000882        0.000017          1.0
# 10       0.001455      0.000023         0.000885        0.000021          1.0
# ...

# %%
pred_y = grid_model.predict(X_test)

# %%
mean_squared_error(y_test,pred_y)
# Out:
# 2.387342642087474
